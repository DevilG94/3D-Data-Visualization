# %% [markdown]
# ## (1) Generate or Import 3D Data(eg., XYZ Coordinates)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d as ax

# %%
x = [4, 5, 10, 4, 3, 11, 14, 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]
z = [15, 18, 22, 21, 21, 19, 15, 16, 16, 17]

# %%
ax = plt.axes(projection = '3d')

ax.scatter3D(x, y, z, color="green")
plt.show()

# %% [markdown]
# ## (2) Create a Python Script named "3D_Data_Visualization.py";

# %%
#         Save this file name as "3D_Data_Visualization.py"

# %% [markdown]
# ## (3) Use a library like Matplotlib to create a #3D Surface plot;

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data;

X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface;

surf = ax.plot_surface(X, Y, Z, cmap=cm.Paired,
                       linewidth=0, antialiased=False)

# Customize the z axis;

ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))

# A StrMethodFormatter is used automatically;

ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors;

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# ## (4) Cutomize the plot appearance, including colors, shading & labels;

# %% [markdown]
# ## (5) Implement Contour Plots to represent Multi-Dimensional data relationship;

# %%
import matplotlib.tri as tri

# %%
n_angles = 48
n_radii = 8
min_radius = 0.25

# Create the mesh in polar coordinates and compute x, y, z.
radii = np.linspace(min_radius, 0.95, n_radii)
angles = np.linspace(0, 2*np.pi, n_angles, endpoint=False)
angles = np.repeat(angles[..., np.newaxis], n_radii, axis=1)
angles[:, 1::2] += np.pi/n_angles

x = (radii*np.cos(angles)).flatten()
y = (radii*np.sin(angles)).flatten()
z = (np.cos(radii)*np.cos(3*angles)).flatten()

# Create a custom triangulation.
triang = tri.Triangulation(x, y)

# Mask off unwanted triangles.
triang.set_mask(np.hypot(x[triang.triangles].mean(axis=1),
                         y[triang.triangles].mean(axis=1))
                < min_radius)

ax = plt.figure().add_subplot(projection='3d')
ax.tricontour(triang, z, cmap=plt.cm.prism_r)

# Customize the view angle so it's easier to understand the plot.
ax.view_init(elev=45.)

plt.show()

# %% [markdown]
# ## (6) Save or Display the #3D Visualization to showcase proficiency in  Multi-Dimensional Data Visualization;
